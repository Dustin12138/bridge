# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## seq 6

# %%
physics=[1.032916188,0.887161434,1.010202646,1.086146593,0.988449872,1.181446195,1.008404255,0.98674196,1.049928308,0.928455949,1.057647347,1.167669058,0.889236987,0.986100793,1.016561866,0.96547699,0.91487962,1.023516178]

# %%
n_p=[1.0739130973815918,0.972466766834259,0.9844378232955933,1.5336419343948364,1.2501029968261719,1.1177728176116943,1.032454490661621,0.8171303272247314,1.014674186706543,0.970100998878479,1.2295465469360352,1.1340432167053223,1.2093582153320312]

# %%
import numpy as np

# %%
plt.plot(physics,label="With PINN")
plt.plot(n_p,label="No PINN")
plt.plot([np.mean(physics) for i in range(len(physics))],label="With PINN average loss",linestyle="dashed")

plt.plot([np.mean(n_p) for i in range(len(physics))],label="Without PINN average loss",linestyle="dashed")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Reconstruction Loss")
plt.savefig("seq6_rec_loss.png")
plt.show()

# %%
physics_v=[0.92735666,0.929062545,0.932714045,0.930763364,0.927674949,0.931565166,0.928048193,0.92716074,0.930867195,0.929025531,0.928527415,0.929461062,0.928614438,0.927685201,0.928125203,0.928120255,0.929273248,0.9289698]

# %%
n_p_v=[0.889707088470459,0.8959692120552063,0.8895889520645142,0.9056239724159241,0.8986481428146362,0.9004406332969666,0.9014710783958435,0.899671196937561,0.8970726132392883,0.8953521847724915,0.8957375288009644,0.8948458433151245,0.8934060335159302]

# %%
plt.plot([i for i in range(len(physics_v))],physics_v,label="With PINN")
plt.plot([i for i in range(len(n_p_v))],n_p_v,label="No PINN")
plt.plot([i for i in range(len(physics_v))],[np.mean(physics_v) for i in range(len(physics_v))],label="With PINN average loss",linestyle="dashed")

plt.plot([i for i in range(len(physics_v))],[np.mean(n_p_v) for i in range(len(physics_v))],label="Without PINN average loss",linestyle="dashed")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Validation Loss")
plt.savefig("seq6_val_loss.png")
plt.show()

# %% [markdown]
# ## Sequence size 5

# %%
physics=[1.104777336,0.973125696,0.922857225,0.928874016,0.964599371,0.909933805,0.93027848,0.923123777,0.895606458,1.05971837,0.94105196]

# %%
n_p=[0.9620557427406311,1.120258092880249,0.8268674612045288,0.8669987916946411,0.9929898977279663,0.7160566449165344,1.1352895498275757,1.0723544359207153,1.051893711090088,0.9034528732299805,1.533779263496399,1.1342567205429077,1.0974304676055908, 0.9814794063568115,0.8522986173629761,0.9228658676147461]

# %%
import numpy as np

# %%
plt.plot(physics,label="With PINN")
plt.plot(n_p,label="No PINN")
plt.plot([np.mean(physics) for i in range(len(n_p))],label="With PINN average loss",linestyle="dashed")

plt.plot([np.mean(n_p) for i in range(len(n_p))],label="Without PINN average loss",linestyle="dashed")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Reconstruction Loss")
plt.savefig("seq5_rec_loss.png")
plt.show()

# %%
physics_v=[0.92735666,0.929062545,0.932714045,0.930763364,0.927674949,0.931565166,0.928048193,0.92716074,0.930867195,0.929025531,0.928527415,0.929461062,0.928614438,0.927685201,0.928125203,0.928120255,0.929273248,0.9289698]

# %%
n_p_v=[0.889707088470459,0.8959692120552063,0.8895889520645142,0.9056239724159241,0.8986481428146362,0.9004406332969666,0.9014710783958435,0.899671196937561,0.8970726132392883,0.8953521847724915,0.8957375288009644,0.8948458433151245,0.8934060335159302]

# %%
plt.plot([i for i in range(len(physics_v))],physics_v,label="With PINN")
plt.plot([i for i in range(len(n_p_v))],n_p_v,label="No PINN")
plt.plot([i for i in range(len(physics_v))],[np.mean(physics_v) for i in range(len(physics_v))],label="With PINN average loss",linestyle="dashed")

plt.plot([i for i in range(len(physics_v))],[np.mean(n_p_v) for i in range(len(physics_v))],label="Without PINN average loss",linestyle="dashed")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Validation Loss")
plt.savefig("seq6_val_loss.png")
plt.show()

# %% [markdown]
# ## Sequence size 4

# %%
physics=[1.084874153,1.221686482,1.137016296,0.915561557,0.989417553,0.954396307,0.894569755,1.008935094,1.22840786,0.95213002,0.944970131]

# %%
n_p=[0.9873562455177307,0.9969235062599182,1.2199381589889526,1.0947383642196655,0.8124109506607056,1.0319414138793945,1.3309687376022339,0.9249275326728821,0.7156789898872375,1.3733375072479248,1.1388150453567505,0.9869911670684814]

# %%
import numpy as np

# %%
plt.plot(physics,label="With PINN")
plt.plot(n_p,label="No PINN")
plt.plot([np.mean(physics) for i in range(len(n_p))],label="With PINN average loss",linestyle="dashed")

plt.plot([np.mean(n_p) for i in range(len(n_p))],label="Without PINN average loss",linestyle="dashed")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Reconstruction Loss")
plt.savefig("seq4_rec_loss.png")
plt.show()

# %%
physics_v=[0.92735666,0.929062545,0.932714045,0.930763364,0.927674949,0.931565166,0.928048193,0.92716074,0.930867195,0.929025531,0.928527415,0.929461062,0.928614438,0.927685201,0.928125203,0.928120255,0.929273248,0.9289698]

# %%
n_p_v=[0.889707088470459,0.8959692120552063,0.8895889520645142,0.9056239724159241,0.8986481428146362,0.9004406332969666,0.9014710783958435,0.899671196937561,0.8970726132392883,0.8953521847724915,0.8957375288009644,0.8948458433151245,0.8934060335159302]

# %%
plt.plot([i for i in range(len(physics_v))],physics_v,label="With PINN")
plt.plot([i for i in range(len(n_p_v))],n_p_v,label="No PINN")
plt.plot([i for i in range(len(physics_v))],[np.mean(physics_v) for i in range(len(physics_v))],label="With PINN average loss",linestyle="dashed")

plt.plot([i for i in range(len(physics_v))],[np.mean(n_p_v) for i in range(len(physics_v))],label="Without PINN average loss",linestyle="dashed")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Validation Loss")
plt.savefig("seq6_val_loss.png")
plt.show()
